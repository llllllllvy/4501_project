# %% [markdown]
# TABLE NAME:
# tb311
# tbTree
# tbRent
# tbZipcodes

# %% [markdown]
# # Part 1: Data Preprocessing

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# ## Download DATA

# %%
token = 'eGoVZwLahX4QKwljgqtidcGuw'
url_311 = "https://data.cityofnewyork.us/resource/erm2-nwe9.json"
url_tree = "https://data.cityofnewyork.us/resource/5rq2-4hqu.json"
start_date = '2015-01-01T00:00:00.000'
end_date = '2023-10-01T00:00.000'
start_date_tree = '01/01/2015'

# %% [markdown]
# ### Download DATA of 311

# %%
data311_url = f"{url_311}?$select=count(*)&$where=created_date>'{start_date}'and created_date<'{end_date}'&$$app_token={token}"
response = requests.get(data311_url)
# with open("data311.json", "wb") as file:
#         file.write(response.content)
num = int(json.loads(response.content)[0]['count'])
num
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/yoyo/Desktop/4501/4501_project/Project.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/Users/yoyo/Desktop/4501/4501_project/Project.ipynb#Y303sZmlsZQ%3D%3D?line=0'>1</a> data311_url = f"{url_311}?$select=count(*)&$where=created_date>'{start_date}'and created_date<'{end_date}'&$$app_token={token}"
#       <a href='vscode-notebook-cell:/Users/yoyo/Desktop/4501/4501_project/Project.ipynb#Y303sZmlsZQ%3D%3D?line=1'>2</a> response = requests.get(data311_url)
#       <a href='vscode-notebook-cell:/Users/yoyo/Desktop/4501/4501_project/Project.ipynb#Y303sZmlsZQ%3D%3D?line=2'>3</a> # with open("data311.json", "wb") as file:
#       <a href='vscode-notebook-cell:/Users/yoyo/Desktop/4501/4501_project/Project.ipynb#Y303sZmlsZQ%3D%3D?line=3'>4</a> #         file.write(response.content)
#
# NameError: name 'url_311' is not defined

# %%
data311_url = f"{url_311}?$$app_token={token}&$select=unique_key,created_date,complaint_type,incident_zip,resolution_action_updated_date,x_coordinate_state_plane,y_coordinate_state_plane,latitude,longitude,:@computed_region_efsh_h5xi&$where=created_date>='{start_date}'and created_date<'{end_date}' &$limit=10000000"
response = requests.get(data311_url) 
data = response.json()
df_data311 = pd.DataFrame(data)
df_data311
# print(df_data311.head())
# Out:
#         unique_key             created_date  \
# 0         58974915  2023-09-30T23:59:58.000
# 1         58972386  2023-09-30T23:59:38.000
# 2         58973465  2023-09-30T23:59:35.000
# 3         58974769  2023-09-30T23:59:34.000
# 4         58968700  2023-09-30T23:59:28.000
# ...            ...                      ...
# 9999995   47194353  2020-08-10T12:11:43.000
# 9999996   47189561  2020-08-10T12:11:40.000
# 9999997   47190325  2020-08-10T12:11:02.000
# 9999998   47188108  2020-08-10T12:11:00.000
# 9999999   47197771  2020-08-10T12:11:00.000
#
#                               complaint_type incident_zip  \
# 0                    Noise - Street/Sidewalk        11226
# 1                        Noise - Residential        11361
# 2                         Noise - Commercial        10002
# 3                        Noise - Residential        11435
# 4                        Noise - Residential        11226
# ...                                      ...          ...
# 9999995                     Blocked Driveway        11377
# 9999996                   Indoor Air Quality        10468
# 9999997  NonCompliance with Phased Reopening        11356
# 9999998                     Dirty Conditions          NaN
# 9999999                     Dirty Conditions        10473
#
#         resolution_action_updated_date x_coordinate_state_plane  \
# 0              2023-10-01T00:16:51.000                   995577
# 1              2023-10-01T00:14:37.000                  1043108
# 2              2023-10-01T00:27:53.000                   988445
# 3              2023-10-01T01:44:49.000                  1040468
# 4              2023-10-01T00:08:41.000                   995919
# ...                                ...                      ...
# 9999995        2020-08-10T12:52:36.000                  1009797
# 9999996        2020-08-10T17:04:45.000                  1012053
# 9999997        2020-08-14T13:29:00.000                  1029348
# 9999998        2020-09-18T12:00:00.000                      NaN
# 9999999        2020-08-17T12:00:00.000                  1025468
#
#         y_coordinate_state_plane            latitude           longitude  \
# 0                         178158  40.655672001198894  -73.95917686020623
# 1                         218698   40.76675595839554  -73.78751847563191
# 2                         201410   40.71949965458691  -73.98486650733275
# 3                         189816  40.687499303408536   -73.7972903094197
# 4                         176894   40.65220215349917   -73.9579464603267
# ...                          ...                 ...                 ...
# 9999995                   211998   40.74852520005724  -73.90779884309966
# 9999996                   252702  40.860239591233366  -73.89948820420176
# 9999997                   226316   40.78774622870991   -73.8371417826674
# 9999998                      NaN                 NaN                 NaN
# 9999999                   240511   40.82672647319608  -73.85106608325964
#
#         :@computed_region_efsh_h5xi
# 0                             13510
# 1                             14196
# 2                             11723
# 3                             24670
# 4                             13510
# ...                             ...
# 9999995                       14787
# 9999996                       11606
# 9999997                       14191
# 9999998                         NaN
# 9999999                       11611
#
# [10000000 rows x 10 columns]

# %%
data311_url = f"{url_311}?$$app_token={token}&$select=unique_key,created_date,complaint_type,incident_zip,resolution_action_updated_date,x_coordinate_state_plane,y_coordinate_state_plane,latitude,longitude,:@computed_region_efsh_h5xi&$where=created_date>='{start_date}'and created_date<'{end_date}' &$limit=10000000&$offset=10000000"
response = requests.get(data311_url) 
data = response.json()
df_data311_1 = pd.concat([df_data311, pd.DataFrame(data)], ignore_index=True)
df_data311_1
# print(df_data311.head())
# Out:
#          unique_key             created_date                 complaint_type  \
# 0          58974915  2023-09-30T23:59:58.000        Noise - Street/Sidewalk
# 1          58972386  2023-09-30T23:59:38.000            Noise - Residential
# 2          58973465  2023-09-30T23:59:35.000             Noise - Commercial
# 3          58974769  2023-09-30T23:59:34.000            Noise - Residential
# 4          58968700  2023-09-30T23:59:28.000            Noise - Residential
# ...             ...                      ...                            ...
# 19999995   34679361  2016-11-01T02:09:00.000                          Noise
# 19999996   34672357  2016-11-01T02:09:00.000            Noise - Residential
# 19999997   34685649  2016-11-01T02:08:30.000                 HEAT/HOT WATER
# 19999998   34679334  2016-11-01T02:08:21.000  General Construction/Plumbing
# 19999999   34686346  2016-11-01T02:07:34.000                     WATER LEAK
#
#          incident_zip resolution_action_updated_date x_coordinate_state_plane  \
# 0               11226        2023-10-01T00:16:51.000                   995577
# 1               11361        2023-10-01T00:14:37.000                  1043108
# 2               10002        2023-10-01T00:27:53.000                   988445
# 3               11435        2023-10-01T01:44:49.000                  1040468
# 4               11226        2023-10-01T00:08:41.000                   995919
# ...               ...                            ...                      ...
# 19999995        10035        2016-11-02T22:30:00.000                  1000105
# 19999996        10040        2016-11-01T02:29:52.000                  1001515
# 19999997        10472        2016-11-01T02:22:25.000                  1018209
# 19999998        11419        2016-11-10T00:00:00.000                  1031447
# 19999999        10453        2016-11-02T13:56:00.000                  1007493
#
#          y_coordinate_state_plane            latitude           longitude  \
# 0                          178158  40.655672001198894  -73.95917686020623
# 1                          218698   40.76675595839554  -73.78751847563191
# 2                          201410   40.71949965458691  -73.98486650733275
# 3                          189816  40.687499303408536   -73.7972903094197
# 4                          176894   40.65220215349917   -73.9579464603267
# ...                           ...                 ...                 ...
# 19999995                   230736   40.79997877461986  -73.94273381900739
# 19999996                   251171   40.85606435468108  -73.93758849825578
# 19999997                   239723  40.824594531459304   -73.8772991398564
# 19999998                   187834   40.68211187789757  -73.82983183641889
# 19999999                   250591   40.85445871431665  -73.91598056093478
#
#          :@computed_region_efsh_h5xi
# 0                              13510
# 1                              14196
# 2                              11723
# 3                              24670
# 4                              13510
# ...                              ...
# 19999995                       13093
# 19999996                       13098
# 19999997                       11610
# 19999998                       24015
# 19999999                       10931
#
# [20000000 rows x 10 columns]

# %%
num3 = num - 20000000
data311_url = f"{url_311}?$$app_token={token}&$select=unique_key,created_date,complaint_type,incident_zip,resolution_action_updated_date,x_coordinate_state_plane,y_coordinate_state_plane,latitude,longitude,:@computed_region_efsh_h5xi&$where=created_date>='{start_date}'and created_date<'{end_date}' &$limit={num3}&$offset=20000000"
response = requests.get(data311_url) 
data = response.json()
df_data311_2 = pd.concat([df_data311_1, pd.DataFrame(data)], ignore_index=True)
df_data311_2
# print(df_data311.head())
# Out:
#          unique_key             created_date           complaint_type  \
# 0          58974915  2023-09-30T23:59:58.000  Noise - Street/Sidewalk
# 1          58972386  2023-09-30T23:59:38.000      Noise - Residential
# 2          58973465  2023-09-30T23:59:35.000       Noise - Commercial
# 3          58974769  2023-09-30T23:59:34.000      Noise - Residential
# 4          58968700  2023-09-30T23:59:28.000      Noise - Residential
# ...             ...                      ...                      ...
# 24334854   29609918  2015-01-01T00:04:44.000          Illegal Parking
# 24334855   29608392  2015-01-01T00:04:28.000          Noise - Vehicle
# 24334856   29607589  2015-01-01T00:01:30.000  Noise - Street/Sidewalk
# 24334857   29610889  2015-01-01T00:01:29.000         Blocked Driveway
# 24334858   29611816  2015-01-01T00:00:50.000         Blocked Driveway
#
#          incident_zip resolution_action_updated_date x_coordinate_state_plane  \
# 0               11226        2023-10-01T00:16:51.000                   995577
# 1               11361        2023-10-01T00:14:37.000                  1043108
# 2               10002        2023-10-01T00:27:53.000                   988445
# 3               11435        2023-10-01T01:44:49.000                  1040468
# 4               11226        2023-10-01T00:08:41.000                   995919
# ...               ...                            ...                      ...
# 24334854        11421        2015-01-01T10:21:37.000                  1022809
# 24334855        10468        2015-01-01T02:23:16.000                  1009923
# 24334856        10031        2015-01-01T00:19:33.000                   997847
# 24334857        10466        2015-01-01T02:41:57.000                  1024816
# 24334858        11420        2015-01-01T02:47:01.000                  1038733
#
#          y_coordinate_state_plane            latitude           longitude  \
# 0                          178158  40.655672001198894  -73.95917686020623
# 1                          218698   40.76675595839554  -73.78751847563191
# 2                          201410   40.71949965458691  -73.98486650733275
# 3                          189816  40.687499303408536   -73.7972903094197
# 4                          176894   40.65220215349917   -73.9579464603267
# ...                           ...                 ...                 ...
# 24334854                   192567   40.69514470265117  -73.86094888534394
# 24334855                   255465   40.86782963689454  -73.90717786644662
# 24334856                   238629  40.821646626438095  -73.95087342885292
# 24334857                   262237   40.88636077906953  -73.85329048666742
# 24334858                   184971  40.674211762243935  -73.80358548685278
#
#          :@computed_region_efsh_h5xi
# 0                              13510
# 1                              14196
# 2                              11723
# 3                              24670
# 4                              13510
# ...                              ...
# 24334854                       24017
# 24334855                       11606
# 24334856                       12428
# 24334857                       11275
# 24334858                       24016
#
# [24334859 rows x 10 columns]

# %%
date311_file_path = "/Users/yoyo/Desktop/4501/Project/data/data311.csv"
with open(date311_file_path, "w", encoding='utf-8') as csv_file:
        df_data311_2.to_csv(csv_file, index=False)

# %% [markdown]
# ### Download DATA of TREE

# %%
dataTree_url = f"{url_tree}?$select=count(*)&$where=created_at>'{start_date_tree}'&$$app_token={token}"
response = requests.get(dataTree_url)
response
num_tree = int(json.loads(response.content)[0]['count'])
num_tree
# Out:
# 683788

# %%
dataTree_url = f"{url_tree}?$$app_token={token}&$where=created_at>='{start_date_tree}'&$limit={num_tree}"
response = requests.get(dataTree_url) 
data = response.json()
df_dataTree = pd.DataFrame(data)
df_dataTree
# Out:
#         created_at tree_id block_id  \
# 0       08/27/2015  180683   348711
# 1       09/03/2015  200540   315986
# 2       09/05/2015  204026   218365
# 3       09/05/2015  204337   217969
# 4       08/30/2015  189565   223043
# ...            ...     ...      ...
# 683783  08/18/2015  155433   217978
# 683784  08/29/2015  183795   348185
# 683785  08/22/2015  166161   401670
# 683786  08/29/2015  184028   504204
# 683787  09/03/2015  200607   306527
#
#                                                  the_geom tree_dbh stump_diam  \
# 0       {'type': 'Point', 'coordinates': [-73.84421521...        3          0
# 1       {'type': 'Point', 'coordinates': [-73.81867945...       21          0
# 2       {'type': 'Point', 'coordinates': [-73.93660770...        3          0
# 3       {'type': 'Point', 'coordinates': [-73.93445615...       10          0
# 4       {'type': 'Point', 'coordinates': [-73.97597938...       21          0
# ...                                                   ...      ...        ...
# 683783  {'type': 'Point', 'coordinates': [-73.95494401...       25          0
# 683784  {'type': 'Point', 'coordinates': [-73.85665019...        7          0
# 683785  {'type': 'Point', 'coordinates': [-74.13651724...       12          0
# 683786  {'type': 'Point', 'coordinates': [-73.90311472...        9          0
# 683787  {'type': 'Point', 'coordinates': [-73.78752645...       23          0
#
#        curb_loc status health                           spc_latin  ...  \
# 0        OnCurb  Alive   Fair                         Acer rubrum  ...
# 1        OnCurb  Alive   Fair                   Quercus palustris  ...
# 2        OnCurb  Alive   Good  Gleditsia triacanthos var. inermis  ...
# 3        OnCurb  Alive   Good  Gleditsia triacanthos var. inermis  ...
# 4        OnCurb  Alive   Good                     Tilia americana  ...
# ...         ...    ...    ...                                 ...  ...
# 683783   OnCurb  Alive   Good                   Quercus palustris  ...
# 683784   OnCurb  Alive   Good                 Cladrastis kentukea  ...
# 683785   OnCurb  Alive   Good                         Acer rubrum  ...
# 683786   OnCurb  Alive   Good                         Acer rubrum  ...
# 683787   OnCurb  Alive   Fair                         Acer rubrum  ...
#
#        st_assem st_senate   nta               nta_name  boro_ct     state  \
# 0            28        16  QN17           Forest Hills  4073900  New York
# 1            27        11  QN49             Whitestone  4097300  New York
# 2            50        18  BK90      East Williamsburg  3044900  New York
# 3            53        18  BK90      East Williamsburg  3044900  New York
# 4            44        21  BK37     Park Slope-Gowanus  3016500  New York
# ...         ...       ...   ...                    ...      ...       ...
# 683783       53        18  BK73  North Side-South Side  3051900  New York
# 683784       28        15  QN17           Forest Hills  4070700  New York
# 683785       63        24  SI07            Westerleigh  5020100  New York
# 683786       86        33  BX41             Mount Hope  2023502  New York
# 683787       25        11  QN41   Fresh Meadows-Utopia  4134100  New York
#
#            latitude     longitude           x_sp           y_sp
# 0       40.72309177  -73.84421522  1027431.14821  202756.768749
# 1       40.79411067  -73.81867946  1034455.70109  228644.837379
# 2       40.71758074   -73.9366077  1001822.83131  200716.891267
# 3       40.71353749  -73.93445616  1002420.35833  199244.253136
# 4       40.66677776  -73.97597938  990913.775046  182202.425999
# ...             ...           ...            ...            ...
# 683783  40.71321078  -73.95494401  996740.685965  199121.636255
# 683784  40.71519444   -73.8566502  1023989.07438  199873.647547
# 683785  40.62076153  -74.13651724  946351.410431   165466.07627
# 683786  40.85082819  -73.90311472  1011053.64553  249271.950653
# 683787  40.73216525  -73.78752646  1043136.35794  206095.538318
#
# [683788 rows x 42 columns]

# %%
dataTree_file_path = "/Users/yoyo/Desktop/4501/4501_project/data/dataTree.csv"
with open(dataTree_file_path, "w", encoding='utf-8') as csv_file:
        df_dataTree.to_csv(csv_file, index=False)

# %% [markdown]
# ## Cleaning & Filtering

# %% [markdown]
# ### Removing unnecessary columns and invalid data point of "zillow_rent_data"

# %%
import pandas as pd
import geopandas as gpd

# %%
import pandas as pd
import geopandas as gpd

zillowdf = pd.read_csv('/Users/yoyo/Desktop/4501/4501_Project/data/zillow_rent_data.csv')
# zillowdf = pd.read_csv("C:/Users/Yining Zhu/OneDrive/桌面/4004pj/zillow_rent_data.csv")

zillowdf= zillowdf.drop(['SizeRank','RegionType','StateName','State','City','Metro','CountyName'], axis=1)
zillowdf.columns = ['regionid','zipcode',*list(map(lambda x:'m'+x[:7].replace('-','_'),zillowdf.columns[2:]))]


def exneg(x):
    if x<0:
        print("There is a negativa number!")
        return np.nan
    else:
        return x

zillowdf.iloc[:,1:] = zillowdf.iloc[:,1:].applymap(exneg)
zillowdf
# Out:
#       regionid  zipcode     m2015_01     m2015_02     m2015_03     m2015_04  \
# 0        91982    77494  1606.206406  1612.779844  1622.201575  1630.392427
# 1        91940    77449  1257.814660  1255.268025  1262.170452  1274.955754
# 2        91733    77084          NaN          NaN          NaN          NaN
# 3        93144    79936          NaN          NaN          NaN          NaN
# 4        62093    11385          NaN  2087.527084          NaN  2149.924252
# ...        ...      ...          ...          ...          ...          ...
# 6717    418163    89158          NaN          NaN          NaN          NaN
# 6718     72017    32461          NaN          NaN          NaN          NaN
# 6719     58956     2876          NaN          NaN          NaN          NaN
# 6720     91179    76005          NaN          NaN          NaN          NaN
# 6721     61618    10004          NaN          NaN          NaN          NaN
#
#          m2015_05     m2015_06     m2015_07     m2015_08  ...     m2022_12  \
# 0     1632.411500  1636.206864  1644.894632  1643.390762  ...  1994.653463
# 1     1285.526052  1295.665673  1296.650395  1300.868081  ...  1749.697900
# 2             NaN          NaN          NaN          NaN  ...  1701.217520
# 3             NaN          NaN          NaN          NaN  ...  1419.480272
# 4     2166.263698  2148.992886  2190.098591  2264.966715  ...  2935.808220
# ...           ...          ...          ...          ...  ...          ...
# 6717          NaN          NaN          NaN          NaN  ...  3281.330738
# 6718          NaN          NaN          NaN          NaN  ...          NaN
# 6719          NaN          NaN          NaN          NaN  ...          NaN
# 6720          NaN          NaN          NaN          NaN  ...  2148.224601
# 6721          NaN          NaN          NaN          NaN  ...  4006.972903
#
#          m2023_01     m2023_02     m2023_03     m2023_04     m2023_05  \
# 0     2027.438438  2042.237444  2049.325559  2016.531345  2023.438976
# 1     1738.217986  1747.305840  1758.407295  1758.891075  1762.980879
# 2     1706.900064  1706.067787  1723.722320  1735.484670  1752.132904
# 3     1458.063897  1471.726681  1466.734658  1456.175660  1462.478506
# 4     2895.699421  2873.209025  2881.906361  2913.546218  2963.964134
# ...           ...          ...          ...          ...          ...
# 6717  3509.210744  3407.499896  3438.041504  3436.371804  3524.703410
# 6718          NaN          NaN          NaN          NaN          NaN
# 6719          NaN          NaN          NaN          NaN          NaN
# 6720  2169.143026  2179.393248  2226.624684  2369.532530  2374.713926
# 6721  4000.923287  4002.584212  4085.513015  4224.569373  4240.040733
#
#          m2023_06     m2023_07     m2023_08     m2023_09
# 0     2031.558202  2046.144009  2053.486247  2055.771355
# 1     1771.751591  1779.338402  1795.384582  1799.631140
# 2     1756.990323  1754.429516  1757.602011  1755.031490
# 3     1466.267391  1490.237063  1488.180414  1494.366097
# 4     3005.735342  3034.413822  3064.476503  3079.585783
# ...           ...          ...          ...          ...
# 6717  3426.708975  3412.249969  3310.302151  3448.166667
# 6718  2583.675563  2590.977335  2639.938102  2702.500000
# 6719          NaN          NaN          NaN  2250.000000
# 6720  2414.638428  2389.749852  2383.185013  2313.944444
# 6721  4286.776061  4270.158740  4353.055657  4355.328283
#
# [6722 rows x 107 columns]

# %%
zillowdf_final_file_path = "/Users/yoyo/Desktop/4501/4501_project/data/zillowdf_final.csv"
with open(zillowdf_final_file_path, "w", encoding='utf-8') as csv_file:
        zillowdf.to_csv(csv_file, index=False)

# %% [markdown]
# ### Normalize the SRID, Removing unnecessary columns and invalid data point of "zipcodes"

# %%
file_path = '/Users/yoyo/Desktop/4501/4501_project/data/nyc_zipcodes.shp'
# file_path = "C:/Users/Yining Zhu/OneDrive/桌面/4004pj/nyc_zipcodes/nyc_zipcodes.shp"
gdf = gpd.read_file(file_path)

target_srid = "4326"
gdf_epsg = gdf.to_crs(epsg=target_srid)
# print(gdf.crs)

gdf_epsg = gdf_epsg.drop(['BLDGZIP','PO_NAME','POPULATION','AREA','STATE','COUNTY','ST_FIPS','CTY_FIPS','URL','SHAPE_AREA','SHAPE_LEN'], axis=1)

gdf_epsg = gdf_epsg.dropna()
gdf_epsg.columns = ['zipcode','geom']
# gdf_epsg.index.name = 'ID'
gdf_epsg
# Out:
#     zipcode                                               geom
# 0     11436  POLYGON ((-73.80585 40.68291, -73.80569 40.682...
# 1     11213  POLYGON ((-73.93740 40.67973, -73.93487 40.679...
# 2     11212  POLYGON ((-73.90294 40.67084, -73.90223 40.668...
# 3     11225  POLYGON ((-73.95797 40.67066, -73.95576 40.670...
# 4     11218  POLYGON ((-73.97208 40.65060, -73.97192 40.650...
# ..      ...                                                ...
# 258   10310  POLYGON ((-74.12065 40.64104, -74.12057 40.641...
# 259   11693  POLYGON ((-73.84076 40.62536, -73.84306 40.627...
# 260   11249  POLYGON ((-73.95805 40.72442, -73.95772 40.724...
# 261   10162  POLYGON ((-73.95133 40.76931, -73.95165 40.769...
# 262   10119  POLYGON ((-73.99354 40.75145, -73.99320 40.751...
#
# [263 rows x 2 columns]

# %%
null_geom_rows = gdf_epsg[gdf_epsg['geom'].isnull()]
null_geom_rows
# Out:
# Empty DataFrame
# Columns: [ZipCode, geom]
# Index: []

# %% [markdown]
# ### Removing unnecessary columns and invalid data point of "Tree_Data"

# %%
treedf = pd.read_csv('/Users/yoyo/Desktop/4501/Project/data/dataTree.csv')
keepco =["tree_id","zipcode","status","health","spc_common","latitude","longitude","x_sp","y_sp"]
treedf = treedf[keepco]
treedf.columns = ["tree_id","ZipCode","status","health","spc_common","latitude","longitude","x_sp","y_sp"]
treedf = treedf.rename(columns = {'ZipCode':'zipcode'})
# treedf = treedf.set_index('tree_id')

if len(treedf.index) == len(set(treedf.index)) and not any(treedf['zipcode'].isnull()):
    print("Each tree_id is unique!")
    print("There is no invalid zipcode!")
    ftreedf = treedf
else:
    print("Something is wrong!")
    ftreedf = "need renew"

ftreedf

# checkcheck()
# treedf
# treedf[treedf.isnull().any(axis=1)]
# any(treedf.isnull())
# Out:
# Each tree_id is unique!
# There is no invalid zipcode!
#         tree_id  zipcode status health           spc_common   latitude  \
# 0        180683    11375  Alive   Fair            red maple  40.723092
# 1        200540    11357  Alive   Fair              pin oak  40.794111
# 2        204026    11211  Alive   Good          honeylocust  40.717581
# 3        204337    11211  Alive   Good          honeylocust  40.713537
# 4        189565    11215  Alive   Good      American linden  40.666778
# ...         ...      ...    ...    ...                  ...        ...
# 683783   155433    11211  Alive   Good              pin oak  40.713211
# 683784   183795    11375  Alive   Good  Kentucky yellowwood  40.715194
# 683785   166161    10314  Alive   Good            red maple  40.620762
# 683786   184028    10457  Alive   Good            red maple  40.850828
# 683787   200607    11365  Alive   Fair            red maple  40.732165
#
#         longitude          x_sp           y_sp
# 0      -73.844215  1.027431e+06  202756.768749
# 1      -73.818679  1.034456e+06  228644.837379
# 2      -73.936608  1.001823e+06  200716.891267
# 3      -73.934456  1.002420e+06  199244.253136
# 4      -73.975979  9.909138e+05  182202.425999
# ...           ...           ...            ...
# 683783 -73.954944  9.967407e+05  199121.636255
# 683784 -73.856650  1.023989e+06  199873.647547
# 683785 -74.136517  9.463514e+05  165466.076270
# 683786 -73.903115  1.011054e+06  249271.950653
# 683787 -73.787526  1.043136e+06  206095.538318
#
# [683788 rows x 9 columns]

# %%
ftreedf.zipcode
# Out:
# 0         11375
# 1         11357
# 2         11211
# 3         11211
# 4         11215
#           ...
# 683783    11211
# 683784    11375
# 683785    10314
# 683786    10457
# 683787    11365
# Name: zipcode, Length: 683788, dtype: int64

# %%
ftreedf_final_file_path = "/Users/yoyo/Desktop/4501/4501_project/data/ftreedf_final.csv"
with open(ftreedf_final_file_path, "w", encoding='utf-8') as csv_file:
        ftreedf.to_csv(csv_file, index=False)

# %% [markdown]
# ### Removing unnecessary columns and invalid data point of "311_Data"

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
data311df = pd.read_csv('/Users/yoyo/Desktop/4501/Project/data/data311.csv')
data311df = data311df.drop([':@computed_region_efsh_h5xi','resolution_action_updated_date'], axis=1)
# data311df = data311df.set_index('unique_key')
data311df
# Out:
# /var/folders/n6/pc1ct2qx01s6yggx10dx3d3c0000gn/T/ipykernel_21145/4209569269.py:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data311df = pd.read_csv('/Users/yoyo/Desktop/4501/Project/data/data311.csv')
#           unique_key             created_date           complaint_type  \
# 0           58974915  2023-09-30T23:59:58.000  Noise - Street/Sidewalk
# 1           58972386  2023-09-30T23:59:38.000      Noise - Residential
# 2           58973465  2023-09-30T23:59:35.000       Noise - Commercial
# 3           58974769  2023-09-30T23:59:34.000      Noise - Residential
# 4           58968700  2023-09-30T23:59:28.000      Noise - Residential
# ...              ...                      ...                      ...
# 24334854    29609918  2015-01-01T00:04:44.000          Illegal Parking
# 24334855    29608392  2015-01-01T00:04:28.000          Noise - Vehicle
# 24334856    29607589  2015-01-01T00:01:30.000  Noise - Street/Sidewalk
# 24334857    29610889  2015-01-01T00:01:29.000         Blocked Driveway
# 24334858    29611816  2015-01-01T00:00:50.000         Blocked Driveway
#
#          incident_zip  x_coordinate_state_plane  y_coordinate_state_plane  \
# 0             11226.0                  995577.0                  178158.0
# 1             11361.0                 1043108.0                  218698.0
# 2             10002.0                  988445.0                  201410.0
# 3             11435.0                 1040468.0                  189816.0
# 4             11226.0                  995919.0                  176894.0
# ...               ...                       ...                       ...
# 24334854      11421.0                 1022809.0                  192567.0
# 24334855      10468.0                 1009923.0                  255465.0
# 24334856      10031.0                  997847.0                  238629.0
# 24334857      10466.0                 1024816.0                  262237.0
# 24334858      11420.0                 1038733.0                  184971.0
#
#            latitude  longitude
# 0         40.655672 -73.959177
# 1         40.766756 -73.787518
# 2         40.719500 -73.984867
# 3         40.687499 -73.797290
# 4         40.652202 -73.957946
# ...             ...        ...
# 24334854  40.695145 -73.860949
# 24334855  40.867830 -73.907178
# 24334856  40.821647 -73.950873
# 24334857  40.886361 -73.853290
# 24334858  40.674212 -73.803585
#
# [24334859 rows x 8 columns]

# %%
# find datatype of incident_zip
# data311df.index.name = 'complaint_id'
data311df.incident_zip.apply(type).unique()
# Out:
# array([<class 'float'>, <class 'str'>], dtype=object)

# %%
zip_str = data311df[data311df.incident_zip.apply(type)==str]
zip_str_null = zip_str[zip_str.incident_zip.isnull()]
# zip_str_null
data311df_remove0 = data311df.drop(zip_str_null.index)

# %%
zip_float = data311df[data311df.incident_zip.apply(type)==float]
zip_float_null = zip_float[zip_float.incident_zip.isnull()]
data311df_remove1 = data311df_remove0.drop(zip_float_null.index)
data311df_remove1
# Out:
#           unique_key             created_date           complaint_type  \
# 0           58974915  2023-09-30T23:59:58.000  Noise - Street/Sidewalk
# 1           58972386  2023-09-30T23:59:38.000      Noise - Residential
# 2           58973465  2023-09-30T23:59:35.000       Noise - Commercial
# 3           58974769  2023-09-30T23:59:34.000      Noise - Residential
# 4           58968700  2023-09-30T23:59:28.000      Noise - Residential
# ...              ...                      ...                      ...
# 24334854    29609918  2015-01-01T00:04:44.000          Illegal Parking
# 24334855    29608392  2015-01-01T00:04:28.000          Noise - Vehicle
# 24334856    29607589  2015-01-01T00:01:30.000  Noise - Street/Sidewalk
# 24334857    29610889  2015-01-01T00:01:29.000         Blocked Driveway
# 24334858    29611816  2015-01-01T00:00:50.000         Blocked Driveway
#
#          incident_zip  x_coordinate_state_plane  y_coordinate_state_plane  \
# 0             11226.0                  995577.0                  178158.0
# 1             11361.0                 1043108.0                  218698.0
# 2             10002.0                  988445.0                  201410.0
# 3             11435.0                 1040468.0                  189816.0
# 4             11226.0                  995919.0                  176894.0
# ...               ...                       ...                       ...
# 24334854      11421.0                 1022809.0                  192567.0
# 24334855      10468.0                 1009923.0                  255465.0
# 24334856      10031.0                  997847.0                  238629.0
# 24334857      10466.0                 1024816.0                  262237.0
# 24334858      11420.0                 1038733.0                  184971.0
#
#            latitude  longitude
# 0         40.655672 -73.959177
# 1         40.766756 -73.787518
# 2         40.719500 -73.984867
# 3         40.687499 -73.797290
# 4         40.652202 -73.957946
# ...             ...        ...
# 24334854  40.695145 -73.860949
# 24334855  40.867830 -73.907178
# 24334856  40.821647 -73.950873
# 24334857  40.886361 -73.853290
# 24334858  40.674212 -73.803585
#
# [23517926 rows x 8 columns]

# %%
data311df_remove1['incident_zip'][data311df_remove1['incident_zip'].isnull()==True]
# Out:
# Series([], Name: incident_zip, dtype: object)

# %%
#？？要用吗 我没用懒得用了
def mixo(x):
    if type(x)==str:
        x = x.replace('O','0')
    return x

# %% [markdown]
# filter the row which there is letter in zipcodes

# %%
import string
all_letters = string.ascii_letters
special = string.punctuation
#判断是否含有字母，如有返回True
def letterin(x):
    if type(x)==str and len(set(x)&set(all_letters))>0:
        return True
    else:
        return False
    
#在不足五位的zip前填充0
def fill0(x):
    return '0'*(5-len(x))+x

#判断是否有数字外的其他符号，如有返回False
def dele(x):
    if len(set(x)-set('1234567890'))>0:
        return False
    else:
        return True

# %%
#去除含有字母的zip
contains_letter = data311df_remove1['incident_zip'].apply(letterin)
rows_with_letter = data311df_remove1[contains_letter]
data311df_remove2 = data311df_remove1.drop(rows_with_letter.index)

#只保留空格.-前的数字 ; O -> 0
col1 = data311df_remove2.incident_zip.apply(str).apply(mixo).apply(lambda x:x.split(' ')[0]).apply(lambda x:x.split('.')[0]).apply(lambda x:x.split('-')[0]).apply(fill0)
#去除zip前的`
col2 = col1.apply(lambda x:x.strip('`'))
#删除有数字外的其他符号zip的所在行
col3 = col2[col2.apply(dele)]

data311df_remove3 = data311df_remove2.loc[col3.index]
data311df_remove3.loc[col3.index,'incident_zip'] = col3

# %%
def to_int(x):
    if np.isnan(x):
        return x
    else:
        return int(x)

# %%
data311df_remove2
# Out:
#           unique_key             created_date           complaint_type  \
# 0           58974915  2023-09-30T23:59:58.000  Noise - Street/Sidewalk
# 1           58972386  2023-09-30T23:59:38.000      Noise - Residential
# 2           58973465  2023-09-30T23:59:35.000       Noise - Commercial
# 3           58974769  2023-09-30T23:59:34.000      Noise - Residential
# 4           58968700  2023-09-30T23:59:28.000      Noise - Residential
# ...              ...                      ...                      ...
# 24334854    29609918  2015-01-01T00:04:44.000          Illegal Parking
# 24334855    29608392  2015-01-01T00:04:28.000          Noise - Vehicle
# 24334856    29607589  2015-01-01T00:01:30.000  Noise - Street/Sidewalk
# 24334857    29610889  2015-01-01T00:01:29.000         Blocked Driveway
# 24334858    29611816  2015-01-01T00:00:50.000         Blocked Driveway
#
#          incident_zip  x_coordinate_state_plane  y_coordinate_state_plane  \
# 0             11226.0                  995577.0                  178158.0
# 1             11361.0                 1043108.0                  218698.0
# 2             10002.0                  988445.0                  201410.0
# 3             11435.0                 1040468.0                  189816.0
# 4             11226.0                  995919.0                  176894.0
# ...               ...                       ...                       ...
# 24334854      11421.0                 1022809.0                  192567.0
# 24334855      10468.0                 1009923.0                  255465.0
# 24334856      10031.0                  997847.0                  238629.0
# 24334857      10466.0                 1024816.0                  262237.0
# 24334858      11420.0                 1038733.0                  184971.0
#
#            latitude  longitude
# 0         40.655672 -73.959177
# 1         40.766756 -73.787518
# 2         40.719500 -73.984867
# 3         40.687499 -73.797290
# 4         40.652202 -73.957946
# ...             ...        ...
# 24334854  40.695145 -73.860949
# 24334855  40.867830 -73.907178
# 24334856  40.821647 -73.950873
# 24334857  40.886361 -73.853290
# 24334858  40.674212 -73.803585
#
# [23517845 rows x 8 columns]

# %%
data311_final = data311df_remove3.rename(columns = {'incident_zip':'zipcode','unique_key':'complaint_id','x_coordinate_state_plane':'x_coordinate','y_coordinate_state_plane':'y_coordinate'})

# %%
data311_final
# Out:
#           complaint_id             created_date           complaint_type  \
# 0             58974915  2023-09-30T23:59:58.000  Noise - Street/Sidewalk
# 1             58972386  2023-09-30T23:59:38.000      Noise - Residential
# 2             58973465  2023-09-30T23:59:35.000       Noise - Commercial
# 3             58974769  2023-09-30T23:59:34.000      Noise - Residential
# 4             58968700  2023-09-30T23:59:28.000      Noise - Residential
# ...                ...                      ...                      ...
# 24334854      29609918  2015-01-01T00:04:44.000          Illegal Parking
# 24334855      29608392  2015-01-01T00:04:28.000          Noise - Vehicle
# 24334856      29607589  2015-01-01T00:01:30.000  Noise - Street/Sidewalk
# 24334857      29610889  2015-01-01T00:01:29.000         Blocked Driveway
# 24334858      29611816  2015-01-01T00:00:50.000         Blocked Driveway
#
#          zipcode  x_coordinate  y_coordinate   latitude  longitude
# 0          11226      995577.0      178158.0  40.655672 -73.959177
# 1          11361     1043108.0      218698.0  40.766756 -73.787518
# 2          10002      988445.0      201410.0  40.719500 -73.984867
# 3          11435     1040468.0      189816.0  40.687499 -73.797290
# 4          11226      995919.0      176894.0  40.652202 -73.957946
# ...          ...           ...           ...        ...        ...
# 24334854   11421     1022809.0      192567.0  40.695145 -73.860949
# 24334855   10468     1009923.0      255465.0  40.867830 -73.907178
# 24334856   10031      997847.0      238629.0  40.821647 -73.950873
# 24334857   10466     1024816.0      262237.0  40.886361 -73.853290
# 24334858   11420     1038733.0      184971.0  40.674212 -73.803585
#
# [23517838 rows x 8 columns]

# %%
data311_final_file_path = "/Users/yoyo/Desktop/4501/4501_project/data/data311_final.csv"
with open(data311_final_file_path, "w", encoding='utf-8') as csv_file:
        data311_final.to_csv(csv_file, index=False)

# %% [markdown]
# # Part2: Storing Data

# %%
# !createdb db_4501

# %%
# !psql --dbname db_4501 -c 'CREATE EXTENSION postgis'
# Out:
# CREATE EXTENSION

# %%
# !pip install psycopg2
# Out:
# Collecting psycopg2
#   Downloading psycopg2-2.9.9.tar.gz (384 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.9/384.9 kB 8.9 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: psycopg2
#   Building wheel for psycopg2 (setup.py) ... done
#   Created wheel for psycopg2: filename=psycopg2-2.9.9-cp311-cp311-macosx_11_0_arm64.whl size=133256 sha256=fedaeabd126c90b54da0d680541093abb23ebaaf59e91845454debb38c2525b5
#   Stored in directory: /Users/yoyo/Library/Caches/pip/wheels/ab/34/b9/78ebef1b3220b4840ee482461e738566c3c9165d2b5c914f51
# Successfully built psycopg2
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.9

# %%
from sqlalchemy import create_engine
import psycopg2

# PostgreSQL连接参数
db_params = {
    'host': 'localhost',
    'port': '5432',
    'user': 'postgres',
    'password': '12200301',
    'database': 'db_4501',
}

# 创建一个SQLAlchemy引擎
engine = create_engine(f"postgresql://{db_params['user']}:{db_params['password']}@{db_params['host']}:{db_params['port']}/{db_params['database']}")

# 读取 schema.sql 文件
with open("schema.sql", "r") as file:
    sql_statements = file.read()

# 连接到 PostgreSQL 数据库
with psycopg2.connect(**db_params) as connection:
    with connection.cursor() as cursor:
        # 使用 psycopg2 执行 SQL 语句
        cursor.execute(sql_statements)

    # 提交更改
    connection.commit()

# 使用 SQLAlchemy 引擎执行一些额外的查询
result = engine.execute("SELECT tree_id FROM trees")
rows = result.fetchall()
for row in rows:
    print(row)

# %%
result = engine.execute("SELECT * FROM trees")
rows = result.fetchall()
for row in rows:
    print(row)

# %%
# !pip install geoalchemy2
# Out:
# Collecting geoalchemy2
#   Obtaining dependency information for geoalchemy2 from https://files.pythonhosted.org/packages/a6/a0/6a1c96ab4f95fb3573ac47f370404a78497509e5883420e9cb09e31a589b/GeoAlchemy2-0.14.2-py3-none-any.whl.metadata
#   Downloading GeoAlchemy2-0.14.2-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: SQLAlchemy>=1.4 in /Users/yoyo/anaconda3/lib/python3.11/site-packages (from geoalchemy2) (1.4.39)
# Requirement already satisfied: packaging in /Users/yoyo/anaconda3/lib/python3.11/site-packages (from geoalchemy2) (23.0)
# Downloading GeoAlchemy2-0.14.2-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 4.7 MB/s eta 0:00:00
# Installing collected packages: geoalchemy2
# Successfully installed geoalchemy2-0.14.2

# %%
from sqlalchemy import create_engine
import psycopg2

# PostgreSQL连接参数
db_params = {
    'host': 'localhost',
    'port': '5432',
    'user': 'postgres',
    'password': '12200301',
    'database': 'db_4501',
}

engine = create_engine(f"postgresql://{db_params['user']}:{db_params['password']}@{db_params['host']}:{db_params['port']}/{db_params['database']}")

# %%
file_path = '/Users/yoyo/Desktop/4501/Project/data/nyc_zipcodes.shp'
# file_path = "C:/Users/Yining Zhu/OneDrive/桌面/4004pj/nyc_zipcodes/nyc_zipcodes.shp"
gdf = gpd.read_file(file_path)

target_srid = "4326"
gdf_epsg = gdf.to_crs(epsg=target_srid)
# print(gdf.crs)

gdf_epsg = gdf_epsg.drop(['BLDGZIP','PO_NAME','POPULATION','AREA','STATE','COUNTY','ST_FIPS','CTY_FIPS','URL','SHAPE_AREA','SHAPE_LEN'], axis=1)

gdf_epsg = gdf_epsg.dropna()
gdf_epsg.columns = ['zipcode','geom']
# gdf_epsg.index.name = 'ID'
gdf_epsg
# Out:
#     zipcode                                               geom
# 0     11436  POLYGON ((-73.80585 40.68291, -73.80569 40.682...
# 1     11213  POLYGON ((-73.93740 40.67973, -73.93487 40.679...
# 2     11212  POLYGON ((-73.90294 40.67084, -73.90223 40.668...
# 3     11225  POLYGON ((-73.95797 40.67066, -73.95576 40.670...
# 4     11218  POLYGON ((-73.97208 40.65060, -73.97192 40.650...
# ..      ...                                                ...
# 258   10310  POLYGON ((-74.12065 40.64104, -74.12057 40.641...
# 259   11693  POLYGON ((-73.84076 40.62536, -73.84306 40.627...
# 260   11249  POLYGON ((-73.95805 40.72442, -73.95772 40.724...
# 261   10162  POLYGON ((-73.95133 40.76931, -73.95165 40.769...
# 262   10119  POLYGON ((-73.99354 40.75145, -73.99320 40.751...
#
# [263 rows x 2 columns]

# %%
gdf_epsg2 = gdf_epsg.set_geometry("geom")
gdf_epsg2.to_postgis(con=engine,name="nyczipcodes",if_exists='replace')

# %%
# 查询数据库表验证数据是否成功写入
table_name = "nyczipcodes"
query = f"SELECT * FROM {table_name}"
result1 = pd.read_sql_query(query, con=engine)
result2 = gpd.read_postgis(query, con=engine)
print(result2)
# Out:
#     zipcode                                               geom
# 0     11436  POLYGON ((-73.80585 40.68291, -73.80569 40.682...
# 1     11213  POLYGON ((-73.93740 40.67973, -73.93487 40.679...
# 2     11212  POLYGON ((-73.90294 40.67084, -73.90223 40.668...
# 3     11225  POLYGON ((-73.95797 40.67066, -73.95576 40.670...
# 4     11218  POLYGON ((-73.97208 40.65060, -73.97192 40.650...
# ..      ...                                                ...
# 258   10310  POLYGON ((-74.12065 40.64104, -74.12057 40.641...
# 259   11693  POLYGON ((-73.84076 40.62536, -73.84306 40.627...
# 260   11249  POLYGON ((-73.95805 40.72442, -73.95772 40.724...
# 261   10162  POLYGON ((-73.95133 40.76931, -73.95165 40.769...
# 262   10119  POLYGON ((-73.99354 40.75145, -73.99320 40.751...
#
# [263 rows x 2 columns]

# %% [markdown]
# ### insert data to table "trees"

# %%
engine = create_engine(f"postgresql://{db_params['user']}:{db_params['password']}@{db_params['host']}:{db_params['port']}/{db_params['database']}")

# 创建示例 DataFrame
file_path = '/Users/yoyo/Desktop/4501/4501_project/data/ftreedf_final.csv'
# file_path = "C:/Users/Yining Zhu/OneDrive/桌面/4004pj/nyc_zipcodes/nyc_zipcodes.shp"
ftreedf = pd.read_csv(file_path)

# 将 DataFrame 写入数据库表
table_name = 'trees'
ftreedf.to_sql(table_name, con=engine, index=False, if_exists='replace')

# 查询数据库表验证数据是否成功写入
query = f"SELECT * FROM {table_name}"
result = pd.read_sql_query(query, con=engine)
print(result)
# Out:
#         tree_id  zipcode status health           spc_common   latitude  \
# 0        180683    11375  Alive   Fair            red maple  40.723092
# 1        200540    11357  Alive   Fair              pin oak  40.794111
# 2        204026    11211  Alive   Good          honeylocust  40.717581
# 3        204337    11211  Alive   Good          honeylocust  40.713537
# 4        189565    11215  Alive   Good      American linden  40.666778
# ...         ...      ...    ...    ...                  ...        ...
# 683783   155433    11211  Alive   Good              pin oak  40.713211
# 683784   183795    11375  Alive   Good  Kentucky yellowwood  40.715194
# 683785   166161    10314  Alive   Good            red maple  40.620762
# 683786   184028    10457  Alive   Good            red maple  40.850828
# 683787   200607    11365  Alive   Fair            red maple  40.732165
#
#         longitude          x_sp           y_sp
# 0      -73.844215  1.027431e+06  202756.768749
# 1      -73.818679  1.034456e+06  228644.837379
# 2      -73.936608  1.001823e+06  200716.891267
# 3      -73.934456  1.002420e+06  199244.253136
# 4      -73.975979  9.909138e+05  182202.425999
# ...           ...           ...            ...
# 683783 -73.954944  9.967407e+05  199121.636255
# 683784 -73.856650  1.023989e+06  199873.647547
# 683785 -74.136517  9.463514e+05  165466.076270
# 683786 -73.903115  1.011054e+06  249271.950653
# 683787 -73.787526  1.043136e+06  206095.538318
#
# [683788 rows x 9 columns]

# %%
query = f"SELECT zipcode  FROM {table_name}"
result = pd.read_sql_query(query, con=engine)
print(result)
# Out:
#         zipcode
# 0         11375
# 1         11357
# 2         11211
# 3         11211
# 4         11215
# ...         ...
# 683783    11211
# 683784    11375
# 683785    10314
# 683786    10457
# 683787    11365
#
# [683788 rows x 1 columns]

# %% [markdown]
# ### insert data to table "complaints311"

# %%
engine = create_engine(f"postgresql://{db_params['user']}:{db_params['password']}@{db_params['host']}:{db_params['port']}/{db_params['database']}")

# 创建示例 DataFrame

batch = 10000000
# 将 DataFrame 写入数据库表
table_name = 'complaints311'
data311_final[0:batch].to_sql(table_name, con=engine, index=False, if_exists='replace')

# 查询数据库表验证数据是否成功写入
query = f"SELECT * FROM {table_name}"
result = pd.read_sql_query(query, con=engine)
print(result)
# Out:
#          complaint_id             created_date           complaint_type  \
# 0            58974915  2023-09-30T23:59:58.000  Noise - Street/Sidewalk
# 1            58972386  2023-09-30T23:59:38.000      Noise - Residential
# 2            58973465  2023-09-30T23:59:35.000       Noise - Commercial
# 3            58974769  2023-09-30T23:59:34.000      Noise - Residential
# 4            58968700  2023-09-30T23:59:28.000      Noise - Residential
# ...               ...                      ...                      ...
# 9999995      46996602  2020-07-27T02:12:12.000      Noise - Residential
# 9999996      47003327  2020-07-27T02:11:57.000  Noise - Street/Sidewalk
# 9999997      47004270  2020-07-27T02:11:46.000         Blocked Driveway
# 9999998      47006114  2020-07-27T02:11:21.000             Noise - Park
# 9999999      46997990  2020-07-27T02:10:36.000  Noise - Street/Sidewalk
#
#         zipcode  x_coordinate  y_coordinate   latitude  longitude
# 0         11226      995577.0      178158.0  40.655672 -73.959177
# 1         11361     1043108.0      218698.0  40.766756 -73.787518
# 2         10002      988445.0      201410.0  40.719500 -73.984867
# 3         11435     1040468.0      189816.0  40.687499 -73.797290
# 4         11226      995919.0      176894.0  40.652202 -73.957946
# ...         ...           ...           ...        ...        ...
# 9999995   11377     1006969.0      207802.0  40.737016 -73.918019
# 9999996   10468     1011271.0      256941.0  40.871877 -73.902298
# 9999997   11368     1023718.0      213624.0  40.752937 -73.857547
# 9999998   11367     1032313.0      202614.0  40.722675 -73.826604
# 9999999   10034     1007193.0      253637.0  40.862820 -73.917055
#
# [10000000 rows x 8 columns]

# %%
batch = 10000000
# 将 DataFrame 写入数据库表
table_name = 'complaints311'
data311_final[batch:batch*2].to_sql(table_name, con=engine, index=False, if_exists='append')

# 查询数据库表验证数据是否成功写入
query = f"SELECT count(*) FROM {table_name} "
result = pd.read_sql_query(query, con=engine)
print(result)
# Out:
#       count
# 0  20000000

# %%
batch = 10000000
# 将 DataFrame 写入数据库表
table_name = 'complaints311'
data311_final[batch*2:].to_sql(table_name, con=engine, index=False, if_exists='append')

# 查询数据库表验证数据是否成功写入
query = f"SELECT count(*)FROM {table_name}"
result = pd.read_sql_query(query, con=engine)
print(result)
# Out:
#       count
# 0  23517838

# %%
table_name = 'complaints311'
query = f"SELECT zipcode FROM {table_name} LIMIT 5"
result = pd.read_sql_query(query, con=engine)
print(result)
# Out:
#   zipcode
# 0   11226
# 1   11361
# 2   10002
# 3   11435
# 4   11226

# %% [markdown]
# ### insert data to table "rents"

# %%
from sqlalchemy import create_engine
import psycopg2

# PostgreSQL连接参数
db_params = {
    'host': 'localhost',
    'port': '5432',
    'user': 'postgres',
    'password': '12200301',
    'database': 'db_4501',
}

engine = create_engine(f"postgresql://{db_params['user']}:{db_params['password']}@{db_params['host']}:{db_params['port']}/{db_params['database']}")

# %%
engine = create_engine(f"postgresql://{db_params['user']}:{db_params['password']}@{db_params['host']}:{db_params['port']}/{db_params['database']}")


file_path = '/Users/yoyo/Desktop/4501/4501_project/data/zillowdf_final.csv'
# file_path = "C:/Users/Yining Zhu/OneDrive/桌面/4004pj/nyc_zipcodes/nyc_zipcodes.shp"
zillowdf = pd.read_csv(file_path)
# 将 DataFrame 写入数据库表
table_name = 'rents'
zillowdf.to_sql(table_name, con=engine, index=False, if_exists='replace')

# 查询数据库表验证数据是否成功写入
query = f"SELECT * FROM {table_name}"
result = pd.read_sql_query(query, con=engine)
print(result)
# Out:
#       regionid  zipcode     m2015_01     m2015_02     m2015_03     m2015_04  \
# 0        91982    77494  1606.206406  1612.779844  1622.201575  1630.392427
# 1        91940    77449  1257.814660  1255.268025  1262.170452  1274.955754
# 2        91733    77084          NaN          NaN          NaN          NaN
# 3        93144    79936          NaN          NaN          NaN          NaN
# 4        62093    11385          NaN  2087.527084          NaN  2149.924252
# ...        ...      ...          ...          ...          ...          ...
# 6717    418163    89158          NaN          NaN          NaN          NaN
# 6718     72017    32461          NaN          NaN          NaN          NaN
# 6719     58956     2876          NaN          NaN          NaN          NaN
# 6720     91179    76005          NaN          NaN          NaN          NaN
# 6721     61618    10004          NaN          NaN          NaN          NaN
#
#          m2015_05     m2015_06     m2015_07     m2015_08  ...     m2022_12  \
# 0     1632.411500  1636.206864  1644.894632  1643.390762  ...  1994.653463
# 1     1285.526052  1295.665673  1296.650395  1300.868081  ...  1749.697900
# 2             NaN          NaN          NaN          NaN  ...  1701.217520
# 3             NaN          NaN          NaN          NaN  ...  1419.480272
# 4     2166.263698  2148.992886  2190.098591  2264.966715  ...  2935.808220
# ...           ...          ...          ...          ...  ...          ...
# 6717          NaN          NaN          NaN          NaN  ...  3281.330738
# 6718          NaN          NaN          NaN          NaN  ...          NaN
# 6719          NaN          NaN          NaN          NaN  ...          NaN
# 6720          NaN          NaN          NaN          NaN  ...  2148.224601
# 6721          NaN          NaN          NaN          NaN  ...  4006.972903
#
#          m2023_01     m2023_02     m2023_03     m2023_04     m2023_05  \
# 0     2027.438438  2042.237444  2049.325559  2016.531345  2023.438976
# 1     1738.217986  1747.305840  1758.407295  1758.891075  1762.980879
# 2     1706.900064  1706.067787  1723.722320  1735.484670  1752.132904
# 3     1458.063897  1471.726681  1466.734658  1456.175660  1462.478506
# 4     2895.699421  2873.209025  2881.906361  2913.546218  2963.964134
# ...           ...          ...          ...          ...          ...
# 6717  3509.210744  3407.499896  3438.041504  3436.371804  3524.703410
# 6718          NaN          NaN          NaN          NaN          NaN
# 6719          NaN          NaN          NaN          NaN          NaN
# 6720  2169.143026  2179.393248  2226.624684  2369.532530  2374.713926
# 6721  4000.923287  4002.584212  4085.513015  4224.569373  4240.040733
#
#          m2023_06     m2023_07     m2023_08     m2023_09
# 0     2031.558202  2046.144009  2053.486247  2055.771355
# 1     1771.751591  1779.338402  1795.384582  1799.631140
# 2     1756.990323  1754.429516  1757.602011  1755.031490
# 3     1466.267391  1490.237063  1488.180414  1494.366097
# 4     3005.735342  3034.413822  3064.476503  3079.585783
# ...           ...          ...          ...          ...
# 6717  3426.708975  3412.249969  3310.302151  3448.166667
# 6718  2583.675563  2590.977335  2639.938102  2702.500000
# 6719          NaN          NaN          NaN  2250.000000
# 6720  2414.638428  2389.749852  2383.185013  2313.944444
# 6721  4286.776061  4270.158740  4353.055657  4355.328283
#
# [6722 rows x 107 columns]

# %% [markdown]
# ## 添加index

# %%
from sqlalchemy import create_engine, Index, MetaData, Table

# 创建与 PostgreSQL 数据库的连接
ngine = create_engine(f"postgresql://{db_params['user']}:{db_params['password']}@{db_params['host']}:{db_params['port']}/{db_params['database']}")

# 获取表的元数据
metadata = MetaData(bind=engine)

# 指定表名和列名
table_name = 'NYCzipcodes'
column_name = 'zipcode'

# 获取表对象
table = Table(table_name, metadata, autoload=True, autoload_with=engine)

# 指定索引名称，这里假设为 your_index_name
index_name = 'zip_index'

# 创建索引对象
index = Index(index_name, table.c[column_name])

# 创建索引
index.create(bind=engine)

# %% [markdown]
# ### Test

# %%
# !psql --dbname db_4501 -f schema.sql
# Out:
# psql:schema.sql:5: NOTICE:  relation "nyczipcodes" already exists, skipping
# CREATE TABLE
# CREATE INDEX
# psql:schema.sql:20: NOTICE:  relation "complaints311" already exists, skipping
# CREATE TABLE
# psql:schema.sql:32: NOTICE:  relation "trees" already exists, skipping
# CREATE TABLE
# psql:schema.sql:142: NOTICE:  relation "rents" already exists, skipping
# CREATE TABLE

# %%
table_name = 'complaints311'
# zillowdf.to_sql(table_name, con=engine, index=False, if_exists='replace')

# 查询数据库表验证数据是否成功写入
query = f"SELECT * FROM {table_name}"
result = pd.read_sql_query(query, con=engine)
print(result)

# %% [markdown]
# # Part 3: Understanding Data

# %%
col3
# Out:
# unique_key
# 58974915    11226
# 58972386    11361
# 58973465    10002
# 58974769    11435
# 58968700    11226
#             ...
# 29609918    11421
# 29608392    10468
# 29607589    10031
# 29610889    10466
# 29611816    11420
# Name: incident_zip, Length: 23517838, dtype: object

# %% [markdown]
# ## Query 1

# %%
query1 = """
        SELECT complaints311.ZipCode,
               COUNT(complaint_id) AS complaint_num
        FROM complaints311
        WHERE created_date BETWEEN '2022-10-01T00:00:00.000' AND '2023-09-30T23:59:59.999'
        GROUP BY complaints311.ZipCode;
        """
result = pd.read_sql_query(query1, con=engine)
print(result)
# Out:
#     zipcode  complaint_num
# 0     00000              2
# 1     00083              2
# 2     02026              1
# 3     02062              4
# 4     03833              1
# ..      ...            ...
# 371   94402              1
# 372   94804              1
# 373   95834              1
# 374   97208              1
# 375   98057              2
#
# [376 rows x 2 columns]

# %%
sql_file_path = 'query1.sql'

with open(sql_file_path, 'r') as sql_file:
    sql_content = sql_file.read()
# print(sql_content)

result = pd.read_sql_query(sql_content , con=engine)
print(result)
# Out:
#     zipcode  complaint_num
# 0     00000              2
# 1     00083              2
# 2     02026              1
# 3     02062              4
# 4     03833              1
# ..      ...            ...
# 371   94402              1
# 372   94804              1
# 373   95834              1
# 374   97208              1
# 375   98057              2
#
# [376 rows x 2 columns]

# %% [markdown]
# ## Query2

# %%
query2 = """
        SELECT zipcode,
               COUNT(tree_id) AS tree_num
        FROM trees
        GROUP BY zipcode
        ORDER BY COUNT(tree_id) DESC
        LIMIT 10
        """

result = pd.read_sql_query(query2, con=engine)
print(result)
# Out:
#    zipcode  tree_num
# 0    10312     22186
# 1    10314     16905
# 2    10306     13030
# 3    10309     12650
# 4    11234     11253
# 5    11385     10937
# 6    11357      9449
# 7    11207      8634
# 8    11434      8274
# 9    11208      8245

# %% [markdown]
# ## Query3

# %%
query3 = """
        WITH tb_most_tree_zipcode as (SELECT zipcode,
                                            COUNT(tree_id) AS tree_num
                                      FROM trees
                                      GROUP BY zipcode
                                      ORDER BY COUNT(tree_id) DESC
                                      LIMIT 10)
        SELECT zipcode,
               average_rent
        FROM(
        SELECT t1.zipcode,
               t1.tree_num,
               ROUND(AVG(t2.m2023_08)::numeric, 2) AS average_rent
        FROM tb_most_tree_zipcode AS t1
        JOIN rents AS t2 ON t1.zipcode = t2.zipcode
        GROUP BY t1.zipcode, t1.tree_num
        ORDER BY t1.tree_num DESC)
        """
        
result = pd.read_sql_query(query3, con=engine)
print(result)
# Out:
#    zipcode  average_rent
# 0    10312       1775.09
# 1    10314       2465.47
# 2    10306       2331.54
# 3    10309       1832.01
# 4    11234       2312.31
# 5    11385       3064.48
# 6    11357       2458.81
# 7    11207       3079.09
# 8    11434       2645.92
# 9    11208       2737.55

# %%
query3 = """
        WITH tb_most_tree_zipcode as (SELECT zipcode,
                                            COUNT(tree_id) AS tree_num
                                      FROM trees
                                      GROUP BY zipcode
                                      ORDER BY COUNT(tree_id) DESC
                                      LIMIT 10)
        
        SELECT t1.zipcode,
               t1.tree_num,
               ROUND(AVG(t2.m2023_08)::numeric, 2) AS average_rent
        FROM tb_most_tree_zipcode AS t1
        JOIN rents AS t2 ON t1.zipcode = t2.zipcode
        GROUP BY t1.zipcode, t1.tree_num
        ORDER BY t1.tree_num DESC
        """
        
result = pd.read_sql_query(query3, con=engine)
print(result)
# Out:
#    zipcode  tree_num  average_rent
# 0    10312     22186       1775.09
# 1    10314     16905       2465.47
# 2    10306     13030       2331.54
# 3    10309     12650       1832.01
# 4    11234     11253       2312.31
# 5    11385     10937       3064.48
# 6    11357      9449       2458.81
# 7    11207      8634       3079.09
# 8    11434      8274       2645.92
# 9    11208      8245       2737.55

# %% [markdown]
# ## Query4

# %%
from sqlalchemy import create_engine
import psycopg2
import pandas as pd

# PostgreSQL连接参数
db_params = {
    'host': 'localhost',
    'port': '5432',
    'user': 'postgres',
    'password': '12200301',
    'database': 'db_4501',
}

engine = create_engine(f"postgresql://{db_params['user']}:{db_params['password']}@{db_params['host']}:{db_params['port']}/{db_params['database']}")

# %%
query = "SELECT * FROM trees limit 5"
result = pd.read_sql_query(query, con=engine)
print(result)
# Out:
#    tree_id  zipcode status health       spc_common   latitude  longitude  \
# 0   180683    11375  Alive   Fair        red maple  40.723092 -73.844215
# 1   200540    11357  Alive   Fair          pin oak  40.794111 -73.818679
# 2   204026    11211  Alive   Good      honeylocust  40.717581 -73.936608
# 3   204337    11211  Alive   Good      honeylocust  40.713537 -73.934456
# 4   189565    11215  Alive   Good  American linden  40.666778 -73.975979
#
#            x_sp           y_sp
# 0  1.027431e+06  202756.768749
# 1  1.034456e+06  228644.837379
# 2  1.001823e+06  200716.891267
# 3  1.002420e+06  199244.253136
# 4  9.909138e+05  182202.425999

# %%
query = """
        SELECT zipcode,
               ROUND(AVG(m2023_01)::numeric, 2)
               FROM rents
               GROUP BY zipcode
               ORDER BY ROUND(AVG(2023_01)::numeric, 2) ASC
        """
result = pd.read_sql_query(query, con=engine)
print(result)  
result.zipcode.dtype
# Out:
#       zipcode    round
# 0       11233  2769.88
# 1       92865      NaN
# 2       30052  2180.69
# 3       33711  1897.24
# 4       91786  2312.16
# ...       ...      ...
# 6717     6107  2007.09
# 6718    34957  2959.17
# 6719    46236  1721.95
# 6720    80550  2386.38
# 6721    95003      NaN
#
# [6722 rows x 2 columns]
# dtype('int64')

# %%
query0 = """
        (SELECT zipcode,
                                              ROUND(AVG(m2023_01)::numeric, 2) AS average_rent
                                       FROM rents
                                       GROUP BY zipcode
                                       HAVING ROUND(AVG(m2023_01)::numeric, 2) IS NOT NULL
                                       ORDER BY ROUND(AVG(m2023_01)::numeric, 2) ASC
                                       LIMIT 10)
                                       UNION ALL
                                       (SELECT zipcode,
                                              ROUND(AVG(m2023_01)::numeric, 2) AS average_rent
                                       FROM rents
                                       GROUP BY zipcode
                                       HAVING ROUND(AVG(m2023_01)::numeric, 2) IS NOT NULL
                                       ORDER BY ROUND(AVG(m2023_01)::numeric, 2) DESC
                                       LIMIT 10)
        """
result = pd.read_sql_query(query0, con=engine)
print(result)  
result.zipcode.dtype
# Out:
#     zipcode  average_rent
# 0     67501        631.74
# 1     61832        648.49
# 2     48503        701.58
# 3     72114        723.04
# 4     50702        723.07
# 5     52807        730.20
# 6     52001        735.53
# 7     67214        736.65
# 8     50701        741.29
# 9     68508        756.50
# 10    11963      41561.34
# 11    11968      38626.57
# 12    81611      33056.44
# 13    11937      32893.57
# 14    11954      23662.30
# 15    90210      13075.74
# 16    90265      12859.56
# 17    90067      10907.39
# 18    34102      10022.13
# 19    33480       8609.28
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/yoyo/Desktop/4501/4501_project/Project.ipynb Cell 88 line 2
#      <a href='vscode-notebook-cell:/Users/yoyo/Desktop/4501/4501_project/Project.ipynb#Y452sZmlsZQ%3D%3D?line=18'>19</a> print(result)
#      <a href='vscode-notebook-cell:/Users/yoyo/Desktop/4501/4501_project/Project.ipynb#Y452sZmlsZQ%3D%3D?line=19'>20</a> result.zipcode.dtype
# ---> <a href='vscode-notebook-cell:/Users/yoyo/Desktop/4501/4501_project/Project.ipynb#Y452sZmlsZQ%3D%3D?line=20'>21</a> rents.zipcode.dtype
#
# NameError: name 'rents' is not defined

# %%
q1 = """
    select t2.zipcode,
    cOUNT(t2.complaint_id) AS tree_num
    from complaints311 as t2 
    where zipcode ='11968'
    group by 1
    """

result = pd.read_sql_query(q1, con=engine)
print(result) 


COUNT(t3.complaint_id) AS complaint_num
LEFT JOIN complaints311 AS t3 ON t1.zipcode  = t3.zipcode
# Out:
#   zipcode  tree_num
# 0   11968         1

# %%
q ="""SELECT column_name, data_type
FROM information_schema.columns
WHERE table_name = 'complaints311' AND column_name = 'zipcode';
"""
result = pd.read_sql_query(q, con=engine)
print(result)
# Out:
#   column_name data_type
# 0     zipcode      text

# %%
query4 = """
        WITH 
        lowest_highest_rent_zipcode as((SELECT zipcode,
                                              ROUND(AVG(m2023_01)::numeric, 2) AS average_rent
                                       FROM rents
                                       GROUP BY zipcode
                                       HAVING ROUND(AVG(m2023_01)::numeric, 2) IS NOT NULL
                                       ORDER BY ROUND(AVG(m2023_01)::numeric, 2) ASC
                                       LIMIT 5)
                                       UNION ALL
                                       (SELECT zipcode,
                                              ROUND(AVG(m2023_01)::numeric, 2) AS average_rent
                                       FROM rents
                                       GROUP BY zipcode
                                       HAVING ROUND(AVG(m2023_01)::numeric, 2) IS NOT NULL
                                       ORDER BY ROUND(AVG(m2023_01)::numeric, 2) DESC
                                       LIMIT 5))
                                               
        SELECT t1.zipcode,
               t1.average_rent,
               COUNT(t2.tree_id) AS tree_num,
               COUNT(t3.complaint_id) AS complaint_num
        FROM lowest_highest_rent_zipcode as t1
        LEFT JOIN trees AS t2 ON t1.zipcode = t2.zipcode
        LEFT JOIN complaints311 AS t3 ON cast(t1.zipcode as text) = t3.zipcode
        GROUP BY t1.zipcode, t1.average_rent
        ORDER BY t1.average_rent
        """
result = pd.read_sql_query(query4, con=engine)
print(result)
# Out:
#    zipcode  average_rent  tree_num  complaint_num
# 0    67501        631.74         0              0
# 1    61832        648.49         0              0
# 2    48503        701.58         0              0
# 3    72114        723.04         0              0
# 4    50702        723.07         0              0
# 5    11954      23662.30         0              0
# 6    11937      32893.57         0              1
# 7    81611      33056.44         0              0
# 8    11968      38626.57         0              1
# 9    11963      41561.34         0              5

# %% [markdown]
# #### 不知道是啥

# %%
query5 = """
        SELECT t2.zipcode,
               COUNT(t1.tree_id) AS tree_num
        FROM trees AS t1
        JOIN nyczipcodes AS t2 ON ST_Within(ST_Transform(ST_SetSRID(ST_MakePoint(t1.longitude, t1.latitude), 4326), 4326), ST_SetSRID(t2.geom, 4326))
        GROUP BY t2.zipcode
        ORDER BY 2 DESC
        LIMIT 10
        """
result = pd.read_sql_query(query5, con=engine)
print(result)
# Out:
#   zipcode  tree_num
# 0   10312     22186
# 1   10314     16905
# 2   10306     13030
# 3   10309     12650
# 4   11234     11253
# 5   11385     10937
# 6   11357      9449
# 7   11207      8635
# 8   11434      8274
# 9   11208      8246

# %%
query6 = """
        SELECT tree_id,
               spc_common AS species,
               health,
               status,
               (longitude,Latitude) AS location
        FROM trees
        WHERE ST_DWithin(
            ST_MakePoint(longitude, Latitude)::geography,
            ST_MakePoint(-73.96253174434912, 40.80737875669467)::geography,
            805 )
         """
result = pd.read_sql_query(query6, con=engine)
print(result)
# Out:
#       tree_id           species health status                    location
# 0      198514           pin oak   Good  Alive   (-73.9620798,40.80230109)
# 1      209919  London planetree   Good  Alive  (-73.96331506,40.80881155)
# 2      209921  London planetree   Good  Alive  (-73.96340334,40.80874458)
# 3      203887        willow oak   Good  Alive  (-73.96071917,40.80572583)
# 4      196440      American elm   Fair  Alive  (-73.96412322,40.81114538)
# ...       ...               ...    ...    ...                         ...
# 2874   198519  London planetree   Fair  Alive   (-73.96145848,40.8020398)
# 2875   186783       scarlet oak   Good  Alive  (-73.96550795,40.80376221)
# 2876   203888  Japanese zelkova   Fair  Alive  (-73.96115906,40.80590977)
# 2877   196620              None   None  Stump   (-73.9679977,40.80593773)
# 2878   189411              None   None   Dead  (-73.95952587,40.80792715)
#
# [2879 rows x 5 columns]

# %% [markdown]
# # Part 4: Visualizing Data

# %%
visual_1 = """
        SELECT SUBSTR(created_date,1,10) AS day,
               complaint_type,
               COUNT(complaint_id) AS complaint_num
        FROM complaints311
        WHERE created_date BETWEEN '2022-10-01T00:00:00.000' AND '2023-09-30T23:59:59.999'
        GROUP BY 1,2
        """
result = pd.read_sql_query(visual_1, con=engine)
print(result)
# Out:
#               day       complaint_type  complaint_num
# 0      2022-10-01       Abandoned Bike              4
# 1      2022-10-01    Abandoned Vehicle            115
# 2      2022-10-01       Adopt-A-Basket              1
# 3      2022-10-01  AHV Inspection Unit              1
# 4      2022-10-01          Air Quality             17
# ...           ...                  ...            ...
# 44922  2023-09-30           WATER LEAK            261
# 44923  2023-09-30    Water Maintenance             31
# 44924  2023-09-30        Water Quality              2
# 44925  2023-09-30         Water System             75
# 44926  2023-09-30  Wood Pile Remaining              3
#
# [44927 rows x 3 columns]
